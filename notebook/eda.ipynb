# %%
import pandas as pd
import numpy as np


data = pd.read_csv("https://raw.githubusercontent.com/sunil-dhakad/data-folder/main/marketing_campaign.csv", sep="\t")
data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 5
#       1 import pandas as pd
#       2 import numpy as np
# ----> 5 data = pd.read_csv("https://raw.githubusercontent.com/sunil-dhakad/data-folder/main/marketing_campaign.csv", sep="\t")
#       6 data.head()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
# ...

# %%
#Importing the Libraries
import numpy as np
import pandas as pd
import datetime
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import colors
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
#from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt, numpy as np
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import AgglomerativeClustering
from matplotlib.colors import ListedColormap
from sklearn import metrics
import warnings
import sys
if not sys.warnoptions:
    warnings.simplefilter("ignore")
np.random.seed(42)

# %%
data.info()##income 2016 rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
df=data.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2216 entries, 0 to 2239
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2216 non-null   int64
#  1   Year_Birth           2216 non-null   int64
#  2   Education            2216 non-null   object
#  3   Marital_Status       2216 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2216 non-null   int64
#  6   Teenhome             2216 non-null   int64
#  7   Dt_Customer          2216 non-null   object
#  8   Recency              2216 non-null   int64
#  9   MntWines             2216 non-null   int64
#  10  MntFruits            2216 non-null   int64
#  11  MntMeatProducts      2216 non-null   int64
#  12  MntFishProducts      2216 non-null   int64
#  13  MntSweetProducts     2216 non-null   int64
#  14  MntGoldProds         2216 non-null   int64
# ...

# %%
df["Dt_Customer"]
# Out:
# 0      2012-04-09
# 1      2014-08-03
# 2      2013-08-21
# 3      2014-10-02
# 4      2014-01-19
#           ...
# 2235   2013-06-13
# 2236   2014-10-06
# 2237   2014-01-25
# 2238   2014-01-24
# 2239   2012-10-15
# Name: Dt_Customer, Length: 2216, dtype: datetime64[ns]

# %%
df["Dt_Customer"] = pd.to_datetime(pd.Series(df["Dt_Customer"]),dayfirst=False)


dates = []
for i in df["Dt_Customer"]:
    i=i.date()
    dates.append(i)
# Out:
# /tmp/ipykernel_19297/2645911798.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Dt_Customer"] = pd.to_datetime(pd.Series(df["Dt_Customer"]),dayfirst=False)

# %% [markdown]
# pd.Timestamp.max(df["Dt_Customer"])

# %%
pd.datetime.max(df["Dt_Customer"])
# Out:
# /tmp/ipykernel_19297/1535080243.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   pd.datetime.max(df["Dt_Customer"])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 pd.datetime.max(df["Dt_Customer"])
#
# TypeError: 'datetime.datetime' object is not callable

# %%
days=[]
for i in df["Dt_Customer"]:
    reslt=df["Dt_Customer"].max() -i
    days.append(reslt)

# %%
days
# Out:
# [Timedelta('971 days 00:00:00'),
#  Timedelta('125 days 00:00:00'),
#  Timedelta('472 days 00:00:00'),
#  Timedelta('65 days 00:00:00'),
#  Timedelta('321 days 00:00:00'),
#  Timedelta('453 days 00:00:00'),
#  Timedelta('753 days 00:00:00'),
#  Timedelta('488 days 00:00:00'),
#  Timedelta('548 days 00:00:00'),
#  Timedelta('268 days 00:00:00'),
#  Timedelta('753 days 00:00:00'),
#  Timedelta('386 days 00:00:00'),
#  Timedelta('386 days 00:00:00'),
#  Timedelta('787 days 00:00:00'),
#  Timedelta('742 days 00:00:00'),
#  Timedelta('712 days 00:00:00'),
#  Timedelta('827 days 00:00:00'),
#  Timedelta('618 days 00:00:00'),
#  Timedelta('1000 days 00:00:00'),
#  Timedelta('850 days 00:00:00'),
#  Timedelta('553 days 00:00:00'),
#  Timedelta('713 days 00:00:00'),
#  Timedelta('35 days 00:00:00'),
#  Timedelta('628 days 00:00:00'),
#  Timedelta('673 days 00:00:00'),
#  Timedelta('558 days 00:00:00'),
#  Timedelta('554 days 00:00:00'),
#  Timedelta('379 days 00:00:00'),
# ...

# %%
day=pd.to_numeric(days,errors="coerce")
day
# Out:
# array([nan, nan, nan, ..., nan, nan, nan])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2216 entries, 0 to 2239
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2216 non-null   int64
#  1   Year_Birth           2216 non-null   int64
#  2   Education            2216 non-null   object
#  3   Marital_Status       2216 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2216 non-null   int64
#  6   Teenhome             2216 non-null   int64
#  7   Dt_Customer          2216 non-null   datetime64[ns]
#  8   Recency              2216 non-null   int64
#  9   MntWines             2216 non-null   int64
#  10  MntFruits            2216 non-null   int64
#  11  MntMeatProducts      2216 non-null   int64
#  12  MntFishProducts      2216 non-null   int64
#  13  MntSweetProducts     2216 non-null   int64
#  14  MntGoldProds         2216 non-null   int64
# ...

# %%
df["age"]=2021-df["Year_Birth"]
# Out:
# /tmp/ipykernel_19297/1952511271.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["age"]=2021-df["Year_Birth"]

# %%
age
# Out:
# 0       64
# 1       67
# 2       56
# 3       37
# 4       40
#         ..
# 2235    54
# 2236    75
# 2237    40
# 2238    65
# 2239    67
# Name: Year_Birth, Length: 2216, dtype: int64

# %%
df["Spent"] = data["MntWines"]+ data["MntFruits"]+ data["MntMeatProducts"]+ data["MntFishProducts"]+ data["MntSweetProducts"]+ data["MntGoldProds"]
# Out:
# /tmp/ipykernel_19297/1775979961.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Spent"] = data["MntWines"]+ data["MntFruits"]+ data["MntMeatProducts"]+ data["MntFishProducts"]+ data["MntSweetProducts"]+ data["MntGoldProds"]

# %%
df.Education
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.Education
#
# NameError: name 'df' is not defined
